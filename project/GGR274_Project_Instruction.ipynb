# %% [markdown]
# # GGR274H1 Final Project Instructions
#
# The final project for this course will entail using data science methods, including programming and statistical analysis, to answer a research question of your choice. While you are free to use any data source(s) for this project with approval from your TA, we are also providing several datasets concerning Toronto neighbourhoods that you are free to use for your project. **A full list of these neighbourhood datasets and guide to their use is available [here](GGR274_Project_Data_Guide.ipynb).** All data files are contained within the [data folder](data/) (link only works if you open this notebook in JupyterHub).
#
# You will present your findings via a five minute pre-recorded video, where you will present your work in the style of an oral presentation at a conference.
#
# **Due Date: April 2, 23:59**

# %% [markdown]
# ## Deliverables
#
#
# 1. The Jupyter notebook (.ipynb) and related data files (`.csv`, `.xlsx`, `.geojson`, etc.) that produced the slides for the pre-recorded video presentation, to be submitted in [MarkUs](https://markus.teach.cs.toronto.edu/markus/main/login_remote_auth) before by **April 2, 23:59 (11:59 PM)**.
#
#     Here are the instructions for submitting to MarkUs:
#
#     - Clean your Jupyter Notebook file
#
#     - Download your Jupyter Notebook file from JupyterHub and rename it as `Final_Project.ipynb`.
#
#     - Download the data files you used from JupyterHub. Do **NOT** rename the data files.
#
#     - Submit the notebook and the data you used to MarkUs under the **Project** assignment.
#
#         + Ensure that the file structure of your submission remains consistent. If your Jupyter Notebook and data files are all in the same folder, you should submit all of them individually. If your data files are contained in a special `data` subfolder, you should submit that entire subfolder.
#
# 2. A 5 minute pre-recorded video presentation summarizing your analysis.
#
#     - If the Jupyter notebook and other files are submitted after the deadline you will lose 10% of your overall final project mark as long as they are submitted at most 24 hours after the deadline. The project files will not be accepted more than 24 hours after the deadline.

# %% [markdown]
# ## Rubric
#
# This assignment will be assessed based on four components: 1) the contents of your presentation slides, 2) the quality of your video presentation, 3) additional written explanation of your analysis not shown during the presentation, and 4) the reproducibility of the analysis in your Jupyter Notebook.
#
# |  | Grade component                   |  Value
# |--|-----------------------------------|--------
# |1 | Presentation Slides               |  30%
# |2 | Video Presentation                |  30%
# |3 | Technical Appendix                |  30%
# |4 | Reproducibility of Analysis       |  10%

# %% [markdown]
# ### 1. Presentation Slides
#
# - You should produce your conference slides using the JupyterHub Slideshow Extension RISE which is available on the [UofT Jupyterhub](https://jupyter.utoronto.ca). You can use **[this template](GGR274_Project_Template.ipynb)** to produce the slides for your presentation.
#
# - We recommend limiting your presentation to between 5-8 slides, not including the title slide and/or slides to break up sections described below. You may exceed this limit, but may not exceed the maximum presentation length of five minutes.
#
# - Your presentation should include the following sections:
#
#    + **Title Slide:** Must include your name, tutorial section (e.g., TUTXXXX), and the link to your presentation video
#
#    + **Introduction:** Summarize your topic and make an argument for why it is important. Conclude this section with a **specific research question**.
#
#    + **Data & Methods:** Discuss the specific techniques you are using to answer your research question (i.e. summary statistics, graphs/maps, difference tests, correlation, regression, etc.)
#
#    + **Results:** Display the results of your analysis in the form of tables, graphs, and/or maps, along with limited descriptive bullet points as appropriate
#
#    + **Conclusion:** Discuss the broader implications of your findings from a social science perspective. How can your results inform our understanding of how the world works?

# %% [markdown]
# - Your presentation slides should *only* include the following components:
#
#    + Slide titles
#
#    + Bullet points summarizing key ideas and arguments (*not* full paragraphs)
#
#    + Reproducible Python output (i.e., graphs, tables should be produced by Python code but not hard-coded or inserted as an image).
#
# - These slides should generally *not* contain raw Python code, except a single line of code where needed to call a plot.
#
# - See **[tips](GGR274_Project_Slides_Guide.ipynb)** for how to create presentation slides in JupyterHub. As a general rule, you should use `skip` to skip python code cells and `fragment` to show multiple cells in one slide.
#
# - A few guidelines for effective presentation slides:
#
#    + Your slides should be clear, concise, and easy to read quickly.
#
#    + Do not use small fonts.
#
#    + Figures often display information more efficiently than text.
#
#    + Numbered or bulleted lists convey points in slides more effectively than blocks of text.

# %%
import pandas as pd
slides = pd.read_csv('presentation/slides_rubric.csv', keep_default_na=False)
slides.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e3805">
#   <thead>
#     <tr>
#       <th id="T_e3805_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_e3805_level0_col1" class="col_heading level0 col1" >Points</th>
#       <th id="T_e3805_level0_col2" class="col_heading level0 col2" >Excellent</th>
#       <th id="T_e3805_level0_col3" class="col_heading level0 col3" >Good</th>
#       <th id="T_e3805_level0_col4" class="col_heading level0 col4" >Adequate</th>
#       <th id="T_e3805_level0_col5" class="col_heading level0 col5" >Poor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e3805_row0_col0" class="data row0 col0" >Introduction</td>
#       <td id="T_e3805_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_e3805_row0_col2" class="data row0 col2" >The scope of the analysis is clear and questions can be fully addressed using the available data.</td>
#       <td id="T_e3805_row0_col3" class="data row0 col3" >The scope of the analysis is clear and questions can be reasonably addressed using the available data.</td>
#       <td id="T_e3805_row0_col4" class="data row0 col4" >The scope of the analysis is less clear, the questions can somewhat be addressed using the available data with slight modifications.</td>
#       <td id="T_e3805_row0_col5" class="data row0 col5" >The questions are beyond the scope, cannot be reasonably addressed with the available data; need to resort to additional data or complete modification.</td>
#     </tr>
#     <tr>
#       <td id="T_e3805_row1_col0" class="data row1 col0" >Data & Methods</td>
#       <td id="T_e3805_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_e3805_row1_col2" class="data row1 col2" >Clear evidence of creative data wrangling to produce informative variables. </td>
#       <td id="T_e3805_row1_col3" class="data row1 col3" >Appropriate use of data wrangling to create sensible variables.</td>
#       <td id="T_e3805_row1_col4" class="data row1 col4" >Some use of data wrangling to create new variables.</td>
#       <td id="T_e3805_row1_col5" class="data row1 col5" >No evidence of data wrangling to create any variables.</td>
#     </tr>
#     <tr>
#       <td id="T_e3805_row2_col0" class="data row2 col0" >Results (Visuals)</td>
#       <td id="T_e3805_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_e3805_row2_col2" class="data row2 col2" >Choice of graphs are appropriate and creative; graphs reveal useful information and tell a story. Meaningful captions and titles.</td>
#       <td id="T_e3805_row2_col3" class="data row2 col3" >Choice of graphs are appropriate; graphs reveal useful information, but are not self-sufficient. Might require some explaining.</td>
#       <td id="T_e3805_row2_col4" class="data row2 col4" >Choice of graphs are appropriate; graphs reveal some useful information.  Might require some explaining and minor changes to titles/axes/labels, etc.</td>
#       <td id="T_e3805_row2_col5" class="data row2 col5" >A lack of visual aid; graphs are inappropriate, reveal no information.</td>
#     </tr>
#     <tr>
#       <td id="T_e3805_row3_col0" class="data row3 col0" >Results (Statistical Methods)</td>
#       <td id="T_e3805_row3_col1" class="data row3 col1" >6</td>
#       <td id="T_e3805_row3_col2" class="data row3 col2" >The choice of method is appropriate; analyses are complete; diverse and creative use of more than one approach.</td>
#       <td id="T_e3805_row3_col3" class="data row3 col3" >The choice of method is appropriate; some  non-essential analyses are missing</td>
#       <td id="T_e3805_row3_col4" class="data row3 col4" >The choice of method is somewhat appropriate; some analyses are missing.</td>
#       <td id="T_e3805_row3_col5" class="data row3 col5" >The choice of method is inappropriate; essential analyses are missing.</td>
#     </tr>
#     <tr>
#       <td id="T_e3805_row4_col0" class="data row4 col0" >Conclusion</td>
#       <td id="T_e3805_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_e3805_row4_col2" class="data row4 col2" >Results are clearly and completely summarized. Appropriate limitations and concerns clearly stated.</td>
#       <td id="T_e3805_row4_col3" class="data row4 col3" >Results are completely summarized. Some limitations and concerns are stated.</td>
#       <td id="T_e3805_row4_col4" class="data row4 col4" >Some results are summarized. The conclusion is not appropriate and no mentioning of any limitations.</td>
#       <td id="T_e3805_row4_col5" class="data row4 col5" >Results are not summarized and conclusion is missing.</td>
#     </tr>
#     <tr>
#       <td id="T_e3805_row5_col0" class="data row5 col0" >Total</td>
#       <td id="T_e3805_row5_col1" class="data row5 col1" >30</td>
#       <td id="T_e3805_row5_col2" class="data row5 col2" ></td>
#       <td id="T_e3805_row5_col3" class="data row5 col3" ></td>
#       <td id="T_e3805_row5_col4" class="data row5 col4" ></td>
#       <td id="T_e3805_row5_col5" class="data row5 col5" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2. Video Presentation
#
# - You will give a 5 minute presentation of your slides. The presentation should not exceed 5 minutes. Any video beyond 5 minutes will not be viewed by the grading TA (they will have a lot of presentations to grade!), and will not be considered when marking.
#
# - In the beginning of the video, you must clearly present your student ID along with the camera on your face. The grading TA must be able to identify you and your student ID number. **Failure to present your student ID will result in a 0 grade for the video presentation.**
#
# - The presentation should show you speaking on one part of the screen and your slides on another part of the screen.
#
# - You may not work with others in the class, as this is an individual project.  You may discuss the project with professors and the course TAs using office hours.
#
# - The rubric for the oral video presentation is below.

# %%
presentation = pd.read_csv('presentation/presentation_rubric.csv', keep_default_na=False)
presentation.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3088f">
#   <thead>
#     <tr>
#       <th id="T_3088f_level0_col0" class="col_heading level0 col0" >Criteria</th>
#       <th id="T_3088f_level0_col1" class="col_heading level0 col1" >Points</th>
#       <th id="T_3088f_level0_col2" class="col_heading level0 col2" >Excellent</th>
#       <th id="T_3088f_level0_col3" class="col_heading level0 col3" >Good</th>
#       <th id="T_3088f_level0_col4" class="col_heading level0 col4" >Adequate</th>
#       <th id="T_3088f_level0_col5" class="col_heading level0 col5" >Poor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3088f_row0_col0" class="data row0 col0" >Introduction</td>
#       <td id="T_3088f_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_3088f_row0_col2" class="data row0 col2" >Scope of analysis is very well articulated, with purpose of analysis and importance of research questions clearly described.</td>
#       <td id="T_3088f_row0_col3" class="data row0 col3" >Scope of analysis is well articulated, but purpose of analysis and/or importance of research questions could be better described.</td>
#       <td id="T_3088f_row0_col4" class="data row0 col4" >Scope of analysis is less well articulated, and the purpose of analysis or importance of research questions is less clear.</td>
#       <td id="T_3088f_row0_col5" class="data row0 col5" >Explanation is brief or incomplete, and questions are missing or inadequate.</td>
#     </tr>
#     <tr>
#       <td id="T_3088f_row1_col0" class="data row1 col0" >Data & Methods</td>
#       <td id="T_3088f_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_3088f_row1_col2" class="data row1 col2" >Clear and concise description of data wrangling and methods used for analysis.</td>
#       <td id="T_3088f_row1_col3" class="data row1 col3" >Relatively clear description of data wrangling and methods used, but provides too much or too little detail about particular components.</td>
#       <td id="T_3088f_row1_col4" class="data row1 col4" >Description of data wrangling or methods is inadequate.</td>
#       <td id="T_3088f_row1_col5" class="data row1 col5" >Little to no description of data wrangling or methods provided.</td>
#     </tr>
#     <tr>
#       <td id="T_3088f_row2_col0" class="data row2 col0" >Results</td>
#       <td id="T_3088f_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_3088f_row2_col2" class="data row2 col2" >Results are clearly and completely summarized.</td>
#       <td id="T_3088f_row2_col3" class="data row2 col3" >Results are completely summarized, but description could be improved somewhat.</td>
#       <td id="T_3088f_row2_col4" class="data row2 col4" >Description of results is present but incomplete.</td>
#       <td id="T_3088f_row2_col5" class="data row2 col5" >Summary of results is very brief or missing.</td>
#     </tr>
#     <tr>
#       <td id="T_3088f_row3_col0" class="data row3 col0" >Conclusion</td>
#       <td id="T_3088f_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_3088f_row3_col2" class="data row3 col2" >Implications of analysis and appropriate limitations are clearly stated.</td>
#       <td id="T_3088f_row3_col3" class="data row3 col3" >Some implications are limitations are stated.</td>
#       <td id="T_3088f_row3_col4" class="data row3 col4" >Conclusions are not appropriate and discussion of limitations is brief or missing.</td>
#       <td id="T_3088f_row3_col5" class="data row3 col5" >Results are not summarized and conclusion is missing.</td>
#     </tr>
#     <tr>
#       <td id="T_3088f_row4_col0" class="data row4 col0" >Vocabulary</td>
#       <td id="T_3088f_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_3088f_row4_col2" class="data row4 col2" >Accurate use of statistical terms and phrases, and the presentation was professional and polished.</td>
#       <td id="T_3088f_row4_col3" class="data row4 col3" >Good use of statistical terms and phrases whenever necessary. </td>
#       <td id="T_3088f_row4_col4" class="data row4 col4" >Demonstrated efforts to incorporate statistical terms and phrases, but some were used inaccurately.</td>
#       <td id="T_3088f_row4_col5" class="data row4 col5" >Completely inaccurate and wrong use of statistical terms and phrases and signals a lack of understanding.</td>
#     </tr>
#     <tr>
#       <td id="T_3088f_row5_col0" class="data row5 col0" >Delivery</td>
#       <td id="T_3088f_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_3088f_row5_col2" class="data row5 col2" >Well-paced, good volume, and the presenter was confident.</td>
#       <td id="T_3088f_row5_col3" class="data row5 col3" >Good pace, and the presenter seemed confident.</td>
#       <td id="T_3088f_row5_col4" class="data row5 col4" >Pacing could be improved, volume was not consistent.</td>
#       <td id="T_3088f_row5_col5" class="data row5 col5" >Poor pacing, barely audible.</td>
#     </tr>
#     <tr>
#       <td id="T_3088f_row6_col0" class="data row6 col0" >Total</td>
#       <td id="T_3088f_row6_col1" class="data row6 col1" >30</td>
#       <td id="T_3088f_row6_col2" class="data row6 col2" ></td>
#       <td id="T_3088f_row6_col3" class="data row6 col3" ></td>
#       <td id="T_3088f_row6_col4" class="data row6 col4" ></td>
#       <td id="T_3088f_row6_col5" class="data row6 col5" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3. Technical Appendix
#
# In addition to producing streamlined presentation slides, you will also provide a more detailed explanation of your project written in full sentences at the bottom of your notebook. This section should include full paragraphs describing each of the following sections:
#
# - Introduction
#
# - Data & Methods
#
# - Results
#
# - Conclusion

# %%
writing = pd.read_csv('presentation/writing_rubric.csv', keep_default_na=False)
writing.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c0774">
#   <thead>
#     <tr>
#       <th id="T_c0774_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_c0774_level0_col1" class="col_heading level0 col1" >Points</th>
#       <th id="T_c0774_level0_col2" class="col_heading level0 col2" >Excellent</th>
#       <th id="T_c0774_level0_col3" class="col_heading level0 col3" >Good</th>
#       <th id="T_c0774_level0_col4" class="col_heading level0 col4" >Adequate</th>
#       <th id="T_c0774_level0_col5" class="col_heading level0 col5" >Poor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c0774_row0_col0" class="data row0 col0" >Introduction</td>
#       <td id="T_c0774_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_c0774_row0_col2" class="data row0 col2" >Scope of analysis is very well articulated, with purpose of analysis and importance of research questions clearly described.</td>
#       <td id="T_c0774_row0_col3" class="data row0 col3" >Scope of analysis is well articulated, but may require minor revisions to clarify the purpose of analysis and/or importance of research questions.</td>
#       <td id="T_c0774_row0_col4" class="data row0 col4" >Scope of analysis is less well articulated, and may require substantial revisions to clarify the purpose of analysis or importance of research questions.</td>
#       <td id="T_c0774_row0_col5" class="data row0 col5" >Written explanation is brief or incomplete, and questions are missing or inadequate.</td>
#     </tr>
#     <tr>
#       <td id="T_c0774_row1_col0" class="data row1 col0" >Data and Methods</td>
#       <td id="T_c0774_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_c0774_row1_col2" class="data row1 col2" >Clear and concise description of data wrangling and methods used for analysis.</td>
#       <td id="T_c0774_row1_col3" class="data row1 col3" >Relatively clear description of data wrangling and methods used, but provides too much or too little detail about particular components.</td>
#       <td id="T_c0774_row1_col4" class="data row1 col4" >Description of data wrangling or methods is inadequate.</td>
#       <td id="T_c0774_row1_col5" class="data row1 col5" >Little to no description of data wrangling or methods provided.</td>
#     </tr>
#     <tr>
#       <td id="T_c0774_row2_col0" class="data row2 col0" >Results</td>
#       <td id="T_c0774_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_c0774_row2_col2" class="data row2 col2" >Results are clearly and completely summarized.</td>
#       <td id="T_c0774_row2_col3" class="data row2 col3" >Results are completely summarized, but description could be improved somewhat.</td>
#       <td id="T_c0774_row2_col4" class="data row2 col4" >Description of results is present but incomplete.</td>
#       <td id="T_c0774_row2_col5" class="data row2 col5" >Written summary of results is very brief or missing.</td>
#     </tr>
#     <tr>
#       <td id="T_c0774_row3_col0" class="data row3 col0" >Conclusion</td>
#       <td id="T_c0774_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_c0774_row3_col2" class="data row3 col2" >Implications of analysis and appropriate limitations are clearly stated.</td>
#       <td id="T_c0774_row3_col3" class="data row3 col3" >Some implications are limitations are stated.</td>
#       <td id="T_c0774_row3_col4" class="data row3 col4" >Conclusions are not appropriate and discussion of limitations is brief or missing.</td>
#       <td id="T_c0774_row3_col5" class="data row3 col5" >Results are not summarized and conclusion is missing.</td>
#     </tr>
#     <tr>
#       <td id="T_c0774_row4_col0" class="data row4 col0" >Organization</td>
#       <td id="T_c0774_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_c0774_row4_col2" class="data row4 col2" >Contents are very well organized under the appropriate section and subsection headings.</td>
#       <td id="T_c0774_row4_col3" class="data row4 col3" >Contents are organized under the appropriate section and subsection headings.</td>
#       <td id="T_c0774_row4_col4" class="data row4 col4" >Contents are somewhat organized under section and subsection headings. </td>
#       <td id="T_c0774_row4_col5" class="data row4 col5" >Contents are poorly organized under section and subsection headings.</td>
#     </tr>
#     <tr>
#       <td id="T_c0774_row5_col0" class="data row5 col0" >Overall Writing</td>
#       <td id="T_c0774_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_c0774_row5_col2" class="data row5 col2" >Very polished and well written.  </td>
#       <td id="T_c0774_row5_col3" class="data row5 col3" >Few errors in spelling, punctuation, and/or grammar. Mostly clear and understandable.</td>
#       <td id="T_c0774_row5_col4" class="data row5 col4" >Partly unclear, but mostly understandable. Several errors in spelling, punctuation, and/or grammar. </td>
#       <td id="T_c0774_row5_col5" class="data row5 col5" >Too many errors in spelling, punctuation, and/or grammar, which make it unclear and difficult to follow. </td>
#     </tr>
#     <tr>
#       <td id="T_c0774_row6_col0" class="data row6 col0" >Total</td>
#       <td id="T_c0774_row6_col1" class="data row6 col1" >30</td>
#       <td id="T_c0774_row6_col2" class="data row6 col2" ></td>
#       <td id="T_c0774_row6_col3" class="data row6 col3" ></td>
#       <td id="T_c0774_row6_col4" class="data row6 col4" ></td>
#       <td id="T_c0774_row6_col5" class="data row6 col5" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4. Reproducibility
#
# - You will submit both your Jupyter Notebook (.ipynb) and the data files used to complete your analysis. Your TA will attempt to reproduce your analysis, with the following assesssment rubric:
#
#
#     | Mark (out of 10) | Description |
#     |-------------------|-------------|
#     | 10                | Your notebook produces your output with no changes |
#     | 5                 | Your notebook can produce your output after minor changes |
#     | 0                 | We cannot use your notebook to reproduce your output |

# %% [markdown]
# #### Video Recording and Submission Instructions
#
# Follow these instructions to record and submit your video presentation:
#
# 1. First, record your video presentation.
#    - You can refer to this [document](https://library.gwu.edu/sites/default/files/2023-06/How%20to%20Record%20a%20Video%20Presentation%20using%20Zoom.pdf) regarding how to make this recording using Zoom.
#
# 2. Upload your video recording to the University of Toronto MyMedia platform, <https://mymedia.library.utoronto.ca>.
#
# 3. After uploading the video, obtain the "Permanent Link" to the video but clicking on the "Share" button.
#     This link should look something like
#
#     ```
#     https://play.library.utoronto.ca/watch/1234567abcdefg...
#     ```
#
# 4. Add this URL to the top cell of your Jupyter notebook file, and clearly label it as the link to your presentation recording.
#
# 5. Then, submit your Jupyter notebook file and all data used in your Jupyter notebook file to MarkUs under *project: final project submission* assignment.
#
#     **Important:** Your TA will need to be able to see your full notebook file, run the code, and access the video URL, so please double-check notebook, data, and video before making your final submission! If you do not provide a working URL in your initial submission, **you will receive a reduction of __% to your overall project grade**. Failure to promptly provide your TA with a working URL upon request **will result in a grade of 0** for the Video Presentation component.

# %% [markdown]
# ## Additional Notes

# %% [markdown]
# ### Data Analysis Expectations
#
# - To complete your project, you need to "wrangle" and analyze at least one dataset. However, you are also welcome to incorporate more than one dataset, as well as to explore *spatial patterns* using the tools we will cover during the last several weeks of class.
#
# - You will be required to come up with your own research question to address. A few examples of good questions based on the data we have given you are provided below to help get you started. You will need to focus on your unique research question and make choices about what variables are important to _your_ question. You do *not* need to consider every variable in the dataset!
#
# - Your analysis should require data wrangling, exploratory data analysis (plots and summary statistics), statistical tests and modeling. Your project does *not* need to include all of these statistical methods nor does it need to include all of the variables in the data set.  You might also choose not to include all observations, or to make new variables from the data that may be more suitable for answering your questions of interest.
#
# - The goal is *not* to carry out an exhaustive analysis, nor to apply everything you have learned in the course.  The goal is to demonstrate that you have learned how to use Python, that you can appropriately apply the methods we have covered in class to address a research question, and that you can effectively interpret and present the results.

# %% [markdown]
# ### Example Project Questions
#
# Below are a few example questions that can inspire your project topics based on several available datasets. There are many more possibilities available!
#
# **Toronto Neighbourhood Data:** What is the relationship between a given sociodemographic/economic variable and a given health outcome variable?
#
# **Census Microdata:** What is the difference in average incomes/housing costs between two different groups defined based on age, immigration status, location, or something else?
#
# **[Other Microdata Sources]**
