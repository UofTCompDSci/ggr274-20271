# %% [markdown]
# # GGR274 Lab 9
#
# ## Data Storytelling Part 3: Statistical Analysis

# %% [markdown]
# ***
#
# ## Lab Instructions
#
# 1. Think about the research question that you proposed during Lab 7 (or a different question, if your ideas have evolved since then).
#
# 2. Select two variables: an "outcome" (dependent) variable, and an independent variable that you think may be related. This may require reading and joining together multiple datasets!
#
# 3. You will give a "lightning talk" presentation during the next tutorial (Lab #10), based either on your plot from this lab or from the previous lab (Lab #8). Choose which plot you would like to discuss ahead of time and be prepared to speak about it for one minute. This presentation should include:
#
#     - A summary of your research question
#
#     - What your data visualization communicates, and how it helps to address this research question
#
# ### Submission Instructions
#
# 1. Download this file (`Lab_9.ipynb`) from JupyterHub. (See [our JupyterHub Guide](../../../guides/jupyterhub_guide.ipynb) for detailed instructions.)
# 2. Submit this file to MarkUs under the **lab9** assignment by **this Thursday**. (See [our MarkUs Guide](../../../guides/markus_guide.ipynb) for detailed instructions.)

# %% [markdown]
# ***
#
# ## Part 1: Data Preparation
#
# - Load any necessary packages
#
# - Read in your dataset
#
# - Clean the data (selecting the important columns, reclassifying values, etc.)
#
# Note: You may copy any relevant code you developed during the previous labs!

# %%
## Write your code here

# %% [markdown]
# ***
#
# ## Part 2: Correlation
#
# Fill in the `...` to calculate the correlation between your two variables

# %%
## Write your code here
import statistics

statistics.correlation(...)

# %% [markdown]
# ***
#
# ## Part 3: Regression
#
# Fille in the `...` to calculate a linear regression model for the relationship between your two variables

# %%
## Write your code here
from statsmodels.formula.api import ols

model = ols(...).fit()

print(model.params)

# %% [markdown]
# Then, produce the "predicted values" for your outcome variable based on the output of this regression model:

# %%
## Write your code here

# %% [markdown]
# ***
#
# ## Part 4: Scatterplot
#
# - Use the `plot.scatter()` to generate a scatterplot and include a line of best fit
#
# - Ensure that this plot includes a descriptive title and axis labels
#
# Additional plot customizations (i.e. changing colours, styles, etc.) are not required for this exercise, but you are welcome to play around with different options.

# %%
## Write your code here

# %% [markdown]
# ***
#
# ## Part 5: Presentation Summary
#
# Imagine you are giving a presentation about your research project. You have arrived at the point where you are going to describe the above plot to your audience. Fill in the following blanks in one sentence each:
#
# > **You**: “The key point is that ______________________________________.”
# >
# > (Summarize one main idea communicated by your visualization)
# >
# > **You**: “Here we see ________________________________.”
# >
# > (Summarize one interesting feature of your visualization)

# %% [markdown]
# ***
#
# ## Part 6: Write-up
#
# Write one paragraph (250-300 words) explaining your results. What do your correlation and regression analysis tell us about the relationship between these two variables? Is the relationship positive/negative? How much does an increase in one variable impact the other variable? Does the scatterplot display this relationship effectively?

# %% [markdown]
# >Your answer here
