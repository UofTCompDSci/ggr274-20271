# %% [markdown]
# # GGR274 Lab 11
#
# ## Data Storytelling Part 4: Responding to Feedback

# %% [markdown]
# ## Introduction
#
# Today's lab is intended to give you an opportunity to reflect on your experience from last week, communicating the results of your analysis via both data visualization and oral presentation. You will discuss your presentation experience with several of your peers, and then generate an updated version of your visualization.
#
# ## Logistics
#
# This lab notebook is submitted by **this Thursday (March 26) 23:59**.
#
# Submission instructions:
#
# 1. Download this file (`Lab_11.ipynb`) from JupyterHub. (See [our JupyterHub Guide](../../../guides/jupyterhub_guide.ipynb) for detailed instructions.)
# 2. Submit this file to MarkUs under the **lab11** assignment. (See [our MarkUs Guide](../../../guides/markus_guide.ipynb) for detailed instructions.)

# %% [markdown]
# ***
#
# ## Part 1: Group Discussion
#
# Divide into groups with 2-3 people, exchange your experience from the presentation last week, and discuss the following questions:
#
# - Discuss your presentation experience from last week. Which parts of your presentation worked well, and what are the main aspects that you think you could improve?
#
# - Provide feedback to each group member about their visualization from last week. Each person should offer *constructive* feedback about ways that each of their fellow group members could improve their data visualization, or (if there are no specific suggestions) an additional data visualization they could create to further explore their research question.

# %% [markdown]
# ## Part 2: Revision
#
# Following this discussion, use the code block below to either 1) improve your data visualization from last week, or 2) create a new data visualization based on feedback from your peers.

# %%
## Write your new code here
## You can copy and revise the code from your Lab_9 notebook

# %% [markdown]
# ## Part 3: Reflection
#
# Finally, in 200-300 words, write a brief summary discussing:
#
# - The feedback you received from your peers
#
# - How your revised or new data visualization created above responds to this feedback
#
# >Your answer here
