# %% [markdown]
# # GGR274 Lab 11
#
# ## Data Storytelling Part 5: Incorporating Feedback

# %% [markdown]
# ***
#
# ## Lab Instructions
#
# In today's lab, you will discuss your presentation and visualization from the previous week with your peers. You will then make some improvement to your visualization using the experience you learned from the last lab.
#
# ### Submission Instructions
#
# 1. Download this file (`Lab_11.ipynb`) from JupyterHub. (See [our JupyterHub Guide](../../../guides/jupyterhub_guide.ipynb) for detailed instructions.)
# 2. Submit this file to MarkUs under the **lab11** assignment by **this Thursday**. (See [our MarkUs Guide](../../../guides/markus_guide.ipynb) for detailed instructions.)

# %% [markdown]
# ***
#
# ## Part 1: Share Feedback
#
# Divide into groups with 2-3 people, exchange your experience from the presentation last week, and show your group members the visualization you presented.
#
# For each group member:
#
# - Identify the positive points about the visualization/presentation. What works well?
#
# - Identify areas for improvement about the visualization/presentation. What could work better? Provide **constructive** feedback (i.e. actionable suggestions) to each of your group members. These could include minor adjustments to the title/labels/colours, or suggestions about an additional/alternative visualization that could also be included in the final project.

# %% [markdown]
# ***
#
# ## Part 2: Incorporate Feedback
#
# Improve your visulization code (or produce an alternative visualization) based on the suggestions that you received in the code below.

# %%
## Write your new codes here
## You can copy and revise the code from your Lab_8 or Lab_9 notebook

# %% [markdown]
# > In 100-150 words, summarize what you have revised the code and how you think you could improve your presentation

# %% [markdown]
# ***
#
# ## Part 3: Reflection
#
# In 100-150 words, summarize the changes that you have made to your visualization (or the new visualization you have created), and how this improves/enhances your ability to communicate the results of your analysis

# %% [markdown]
# > Your answer here
