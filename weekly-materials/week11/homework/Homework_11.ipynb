# %% [markdown]
# # GG274 Homework 11: Spatial Analysis
#
# ## Logistics
#
# **Due date**: The homework is due 23:59 on Monday, March 29.
#
# You will submit your work on [MarkUs](https://markus.teach.cs.toronto.edu/markus/main/login_remote_auth).
# To submit your work:
#
# 1. Download this file (`Homework_11.ipynb`) from JupyterHub. (See [our JupyterHub Guide](../../../guides/jupyterhub_guide.ipynb) for detailed instructions.)
# 2. Submit this file to MarkUs under the **hw11** assignment. (See [our MarkUs Guide](../../../guides/markus_guide.ipynb) for detailed instructions.)
# All homeworks will take place in a Jupyter notebook (like this one). When you are done, you will download this notebook and submit it to MarkUs.

# %% [markdown]
# For this assignment, you will determine what percentage of Toronto's green space is located within 500 metres of an expressway.

# %% [markdown]
# ## Task 1: Read spatial data
#
# Read in the following three spatial files and assign them to the variable names specified:
#
# - `expressway`: `"toronto_expressways.gpkg"`
# - `greenspace`: `"toronto_greenspacegpkg"`

# %%
import geopandas as gpd

# Write your code below

# %% [markdown]
# ## Task 2: Transform CRS
#
# These layers are currently in the "WGS 84" Coordinate Reference System, which is not ideal for measuring area. Transform both so that they use the CRS `"EPSG:2952"`, producing the following new layers:
# - `expressway_2952`
# - `greenspace_2952`

# %%
# Write your code below

# %% [markdown]
# ## Task 3: Buffer
#
# Create a 500 metre buffer surrounding the expressways layer. Name this layer `expressway_2952_buffer`.

# %%
# Write your code below

# %% [markdown]
# ## Task 4: Clip

# %%
# Write your code below

# %% [markdown]
# ## Task 5: Calculating Area
#
# - Calculate the total amount of greenspace in Toronto. Divide this amount by (1000*1000) to get this figure in square kilometres, and assign this value to `greenspace_total_km2`
#
# - Calculate the amount of greenspace within 500 metres of an expressway. Divide this amount by (1000*1000) to get this figure in square kilometres, and assign this value to `greenspace_expressway_km2`
#
# - Calculate the share of Toronto greenspace located within 500 metres of an expressway, and assign this value to `greenspace_expressway_share`.

# %%
# Write your code below
