# %% [markdown]
# # GGR274 Lab 8
#
# ## Data Storytelling Part 2: Exploring Your Outcome Variable

# %% [markdown]
# ## Introduction
#
# This week, you will identify one or two variables from your dataset and create a data visualization, which you will present during the tutorial in two weeks.
#
# ## Logistics
#
# This lab notebook is submitted by **next Thursday (March 19) 23:59**, containing the following:
#
# - The code to load and process your data and produce the data visualization;
#
# - A **single presentation slide** containing your final plot;
#
# - A write-up of ~250-300 words explaining why you picked this data visualization and what the audience should take away from this image.
#
# Submission instructions:
#
# 1. Download this file (`Lab_8.ipynb`) from JupyterHub. (See [our JupyterHub Guide](../../../guides/jupyterhub_guide.ipynb) for detailed instructions.)
# 2. Submit this file to MarkUs under the **lab08** assignment. (See [our MarkUs Guide](../../../guides/markus_guide.ipynb) for detailed instructions.)

# %% [markdown]
# ***
# ## Lab Instructions
#
# 1. Think about the research question that you proposed during the previous lab (or a different question, if your ideas have evolved since then). What is the **outcome** variable that you are interested in?
#
# 2. Create one data visualization that helps you to visualize your variable. Your visualization should fill the screen, and have a large clear title. The title should communicate the key piece of information that you will be presenting. It should also be able to stand on its own without any additional context.
#
#     - This visualization could be a **histogram** (to display the distribution of a continuous variable), a **bar chart** or **box plot** (to summarize the distribution of your variable within different groups), or a **line chart** (to summarize the values of your variable over time)
#
# 3. You will be given the option to present this visualization in-class during the tutorial on Week 10.

# %% [markdown]
# ## Part 1: Prepare the data
#
# - Load any necessary packages
#
# - Read in your dataset
#
# - Clean the data (selecting the important columns, reclassifying values, etc.)

# %%
## Write your code here

# %% [markdown]
# ## Part 2: Summarize the data
#
# - Use `.describe` to examine the characteristics of your variable of interest

# %%
## Describe your variables here

# %% [markdown]
# ## Part 3: Plot the data
#
# - Use `dataframe.plot` or `matplotlib.pyplot` package to plot your data
#
# - Select an appropriate plot method for your specific use case (histogram, bar, line, boxplot, etc.).
#
# - Ensure that this plot includes a descriptive title and axis labels
#
# Additional plot customizations (i.e. changing colours, styles, etc.) are not required for this exercise, but you are welcome to play around with different options.

# %%
## Write your code here

# %% [markdown]
# ## Part 4: Presentation Summary
#
# Imagine you are giving a presentation about your research project. You have arrived at the point where you are going to describe the above plot to your audience. Fill in the following blanks in one sentence each:
#
# > **You**: “The key point is that ______________________________________.”
# >
# > (Summarize one main idea communicated by your visualization)
# >
# > **You**: “Here we see ________________________________.”
# >
# > (Summarize one interesting feature of your visualization)

# %% [markdown]
# ## Part 5: Write-up
#
# Write one paragraph (250-300 words) explaining your choice of visualization for this exercise.  Why did you choose this style of plot, and what does it communicate to the audience about your outcome variable?

# %% [markdown]
# >Your answer here
