# %% [markdown]
# # GGR274 Lab 7
#
# ## Data Storytelling Part 1: Identifying a Research Question

# %% [markdown]
# ***
#
# ## Lab Instructions
#
# In this lab, you will begin the process of identifying possible datasets and research questions for your final project, the proposal for which is due Monday, March 6. While you are welcome to choose a different question for your project proposal, it is recommended to use this exercise as an opportunity to start brainstorming for your final project!
#
# ### Submission Instructions
#
# 1. Download this file (`Lab_7.ipynb`) from JupyterHub. (See [our JupyterHub Guide](../../../guides/jupyterhub_guide.ipynb) for detailed instructions.)
# 2. Submit this file to MarkUs under the **lab7** assignment by **this Thursday**. (See [our MarkUs Guide](../../../guides/markus_guide.ipynb) for detailed instructions.)

# %% [markdown]
# ***
#
# ## Part 1: Finding Data
#
# In the code cell below, read in and examine the contents of one or more data files. This may include the datasets that we have provided for this project or datasets used previously in this class (census microdata or General Social Survey).

# %%
## Use this code cell to read and examine possible datasets

# %% [markdown]
# ***
#
# ## Part 2: Identifying Variables of Interest
#
# In 2-3 sentences each, identify and describe at least two variables from the datasets you have chosen to explore. These variables may be continuous, categorical, or binary. What do these variables signify, and why are they interesting to consider?

# %% [markdown]
# > 1. Description of first variable
#
# > 2. Description of second variable

# %% [markdown]
# ***
#
# ## Part 3: Crafting A Research Question
#
# Using these variables, identify a possible question that you could ask about the data. This question should involve asking about:
#
# - The **difference** in an outcome variable between different groups/categories
#
# - The **relationship** between two different variables

# %% [markdown]
# > Your answer here
