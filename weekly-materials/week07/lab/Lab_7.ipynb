# %% [markdown]
# # GGR274 Lab 7
#
# ## Data Storytelling Part 1: Identifying a Research Question

# %% [markdown]
# ## Logistics
#
# For this week's lab, you will be exploring possible research questions for your final course project, the proposal for which is due next Monday.
#
# Complete the written tasks in this Jupyter notebook and submit your completed file to [MarkUs](https://markus.teach.cs.toronto.edu/markus/main/login_remote_auth).
# Here are the instructions for submitting to MarkUs (same as last week):
#
# 1. Download this file (`Lab_7.ipynb`) from JupyterHub. (See [our JupyterHub Guide](../../../guides/jupyterhub_guide.ipynb) for detailed instructions.)
# 2. Submit this file to MarkUs under the **lab7** assignment. (See [our MarkUs Guide](../../../guides/markus_guide.ipynb) for detailed instructions.)

# %% [markdown]
# ## Lab Instructions
#
# In this lab, you will begin the process of identifying possible datasets and research questions for your final project. You are *not* required to use the research question developed in this lab for your project proposal, though you are certainly welcome to do so!

# %% [markdown]
# ### Part 1: Finding Data
#
# In the code cell below, read in and examine the contents of at least one data file. This may include the datasets that we have provided, or it can be a dataset that you have downloaded from an online resource, such as [open.toronto.ca](https://open.toronto.ca). If you use any dataset(s) that we have *not* provided, you must also include the link(s) to those datasets below:
#
# > Provide links here

# %%
## Use this code cell to read and examine possible datasets

# %% [markdown]
# ### Part 2: Identifying Variables of Interest
#
# In 2-3 sentences each, identify and describe at least two variables from the dataset you have chosen to explore. These variables may be continuous, categorical, or binary. What do these variables signify, and why are they interesting to consider?

# %% [markdown]
# > 1. Description of first variable
#
# > 2. Description of second variable

# %% [markdown]
# ### Part 3: Crafting A Research Question
#
# Using these variables, identify a possible question that you could ask about the data. This could include asking about:
#
# - The difference in a variable between different groups/categories
#
# - The relationship between two different variables
#
# - The spatial patterns of one or more variables

# %% [markdown]
# > Your answer here
