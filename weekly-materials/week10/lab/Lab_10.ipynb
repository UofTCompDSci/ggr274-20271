# %% [markdown]
# # GGR274 Lab 10
#
# ## Data Storytelling Part 4: Communicating Results

# %% [markdown]
# ## Introduction
#
# In today's lab, you will take 1 minute to present your visualization from Lab #9 during the tutorial. You will then discuss principles of data visualization as a class, and write a reflection after the tutorial session.
#
# ## Logistics
#
# This lab notebook is due by **this Thursday (March 19) 23:59**.
#
# Submission instructions:
#
# 1. Download this file (`Lab_10.ipynb`) from JupyterHub. (See [our JupyterHub Guide](../../../guides/jupyterhub_guide.ipynb) for detailed instructions.)
# 2. Submit this file to MarkUs under the **lab10** assignment. (See [our MarkUs Guide](../../../guides/markus_guide.ipynb) for detailed instructions.)

# %% [markdown]
# ***
#
# ## Part 1: Present Your Visualization!
#
# Present your visualization to the class. This presentation should take approximately 1 minute, and should include:
#
# - A summary of your research question
#
# - What your data visualization communicates, and how it helps to address this research question

# %% [markdown]
# ## Part 2: Reflection
#
# After the presentation in class, discuss the following questions with your colleagues:
#
# - What are the qualities of a good visualization?
#
# - What are the qualities of a good presentation?
#
# - What limitations do you want to avoid when creating and presenting data visualizations?
#
# Then, in 250-300 words in the space below, write up your reflections on what characteristics make a visualization more or less effective at communicating information.

# %% [markdown]
# >Write your reflection here
